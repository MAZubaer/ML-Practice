# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import linear_model
from sklearn.linear_model import Ridge

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv('Melbourne_housing_FULL.csv')
df.shape
# Out:
# (34857, 21)

# %%
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
df.shape
# Out:
# (34857, 21)

# %%
df1= df[['Suburb', 'Rooms', 'Type', 'Method', 'SellerG', 'Regionname', 'Propertycount', 
               'Distance', 'CouncilArea', 'Bedroom2', 'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'Price']]
df1.head()
# Out:
#        Suburb  Rooms Type Method SellerG             Regionname  \
# 0  Abbotsford      2    h     SS  Jellis  Northern Metropolitan
# 1  Abbotsford      2    h      S  Biggin  Northern Metropolitan
# 2  Abbotsford      2    h      S  Biggin  Northern Metropolitan
# 3  Abbotsford      3    u     VB  Rounds  Northern Metropolitan
# 4  Abbotsford      3    h     SP  Biggin  Northern Metropolitan
#
#    Propertycount  Distance         CouncilArea  Bedroom2  Bathroom  Car  \
# 0         4019.0       2.5  Yarra City Council       2.0       1.0  1.0
# 1         4019.0       2.5  Yarra City Council       2.0       1.0  1.0
# 2         4019.0       2.5  Yarra City Council       2.0       1.0  0.0
# 3         4019.0       2.5  Yarra City Council       3.0       2.0  1.0
# 4         4019.0       2.5  Yarra City Council       3.0       2.0  0.0
#
#    Landsize  BuildingArea      Price
# 0     126.0           NaN        NaN
# 1     202.0           NaN  1480000.0
# ...

# %%
df1.isnull().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Method               0
# SellerG              0
# Regionname           3
# Propertycount        3
# Distance             1
# CouncilArea          3
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# Price             7610
# dtype: int64

# %%
df1[['Propertycount', 'Distance', 'Bedroom2', 'Bathroom', 'Car']]= df1[['Propertycount', 'Distance', 'Bedroom2', 'Bathroom', 'Car']].fillna(0)
df1.isnull().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Method               0
# SellerG              0
# Regionname           3
# Propertycount        0
# Distance             0
# CouncilArea          3
# Bedroom2             0
# Bathroom             0
# Car                  0
# Landsize         11810
# BuildingArea     21115
# Price             7610
# dtype: int64

# %%
df1[['Landsize', 'BuildingArea']]= df1[['Landsize', 'BuildingArea']].fillna(df1[['Landsize', 'BuildingArea']].mean())
df1.isnull().sum()
# Out:
# Suburb              0
# Rooms               0
# Type                0
# Method              0
# SellerG             0
# Regionname          3
# Propertycount       0
# Distance            0
# CouncilArea         3
# Bedroom2            0
# Bathroom            0
# Car                 0
# Landsize            0
# BuildingArea        0
# Price            7610
# dtype: int64

# %%
df1.dropna(inplace=True)
df1.isnull().sum()
# Out:
# Suburb           0
# Rooms            0
# Type             0
# Method           0
# SellerG          0
# Regionname       0
# Propertycount    0
# Distance         0
# CouncilArea      0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# Price            0
# dtype: int64

# %%
df1.shape
# Out:
# (27244, 15)

# %%
df1.head()
# Out:
#        Suburb  Rooms Type Method SellerG             Regionname  \
# 1  Abbotsford      2    h      S  Biggin  Northern Metropolitan
# 2  Abbotsford      2    h      S  Biggin  Northern Metropolitan
# 4  Abbotsford      3    h     SP  Biggin  Northern Metropolitan
# 5  Abbotsford      3    h     PI  Biggin  Northern Metropolitan
# 6  Abbotsford      4    h     VB  Nelson  Northern Metropolitan
#
#    Propertycount  Distance         CouncilArea  Bedroom2  Bathroom  Car  \
# 1         4019.0       2.5  Yarra City Council       2.0       1.0  1.0
# 2         4019.0       2.5  Yarra City Council       2.0       1.0  0.0
# 4         4019.0       2.5  Yarra City Council       3.0       2.0  0.0
# 5         4019.0       2.5  Yarra City Council       3.0       2.0  1.0
# 6         4019.0       2.5  Yarra City Council       3.0       1.0  2.0
#
#    Landsize  BuildingArea      Price
# 1     202.0      160.2564  1480000.0
# 2     156.0       79.0000  1035000.0
# ...

# %%
df1.shape
# Out:
# (27244, 15)

# %%
df1['Suburb']= LabelEncoder().fit_transform(df1['Suburb'])
df1['Type']= LabelEncoder().fit_transform(df1['Type'])
df1['Method']= LabelEncoder().fit_transform(df1['Method'])
df1['SellerG']= LabelEncoder().fit_transform(df1['SellerG'])
df1['Regionname']= LabelEncoder().fit_transform(df1['Regionname'])
df1['CouncilArea']= LabelEncoder().fit_transform(df1['CouncilArea'])
df1.head()
# Out:
#    Suburb  Rooms  Type  Method  SellerG  Regionname  Propertycount  Distance  \
# 1       0      2     0       1       32           2         4019.0       2.5
# 2       0      2     0       1       32           2         4019.0       2.5
# 4       0      3     0       3       32           2         4019.0       2.5
# 5       0      3     0       0       32           2         4019.0       2.5
# 6       0      4     0       4      206           2         4019.0       2.5
#
#    CouncilArea  Bedroom2  Bathroom  Car  Landsize  BuildingArea      Price
# 1           31       2.0       1.0  1.0     202.0      160.2564  1480000.0
# 2           31       2.0       1.0  0.0     156.0       79.0000  1035000.0
# 4           31       3.0       2.0  0.0     134.0      150.0000  1465000.0
# 5           31       3.0       2.0  1.0      94.0      160.2564   850000.0
# 6           31       3.0       1.0  2.0     120.0      142.0000  1600000.0

# %%
x= df1.drop('Price', axis=1)
y= df1['Price']

# %%
train_x, test_x, train_y, test_y= train_test_split(x, y, test_size=0.3)
train_x.shape, test_x.shape, train_y.shape, test_y.shape
# Out:
# ((19070, 14), (8174, 14), (19070,), (8174,))

# %%
hmodel= LinearRegression()
hmodel.fit(train_x, train_y)
# Out:
# LinearRegression()

# %%
hmodel.score(test_x, test_y)
# Out:
# 0.4247692422597723

# %%
hmodel.score(train_x, train_y)
# Out:
# 0.4343310488241988

# %%
lassoreg= linear_model.Lasso(alpha=50, max_iter=1000, tol=0.01) 
lassoreg.fit(train_x, train_y)
# Out:
# Lasso(alpha=50, tol=0.01)

# %%
lassoreg.score(test_x, test_y)
# Out:
# 0.4247528988113599

# %%
lassoreg.score(train_x, train_y)
# Out:
# 0.4343309296072503

# %%
ridgereg= Ridge(alpha=50, max_iter=1000, tol=0.01)
ridgereg.fit(train_x, train_y)
# Out:
# Ridge(alpha=50, max_iter=1000, tol=0.01)

# %%
ridgereg.score(test_x, test_y)
# Out:
# 0.4246151904338348

# %%
ridgereg.score(train_x, train_y)
# Out:
# 0.43432160356723604
